# %%
import pandas as pd
import streamlit as st

# %%
date = "26-03-09"
time = "12:30"

# %%
year, mth, day = date.split("-")
year, mth, day
# Out:
# ('26', '03', '09')

# %%
hr, min = time.split(":")
hr, min
# Out:
# ('12', '30')

# %%
pickup_datetime=pd.Timestamp(year=int(year), month=int(mth), day=int(day), hour=int(hr), minute=int(min), tz="US/Eastern")

# %%
pickup_datetime
# Out:
# Timestamp('26-03-09 12:30:00-0456', tz='US/Eastern')

# %%
streamlit run

# %%
date = st.date_input('date of the ride (YY-MM-DDDD) :')
# Out:
# 2026-03-06 11:23:10.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:10.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:10.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:10.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:10.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:10.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:10.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
type(date)
# Out:
# datetime.date

# %%
time = st.time_input('time of day (hh:mm) :')
# Out:
# 2026-03-06 11:23:48.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:48.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:48.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:48.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:48.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:48.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-06 11:23:48.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
date+time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 date+time
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'datetime.time'
